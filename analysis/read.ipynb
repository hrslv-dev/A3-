# %%
import pandas as pd

# %% [markdown]
# ### ReceitasMinerão2014-2025

# %%
df = pd.DataFrame()
df = pd.read_csv('../data.csv/receitas_mineirao_2014_2022.csv')
df
# Out:
#       Ano  receita_ingresso  receita_produtos_internos        data  \
# 0    2017         183179.15                   35041.19  2017-07-29
# 1    2018         180623.99                   23812.53  2018-10-18
# 2    2015         151581.28                   27346.54  2015-12-05
# 3    2015         118258.47                   20007.70  2015-09-28
# 4    2014         127956.58                   24163.02  2014-01-27
# ..    ...               ...                        ...         ...
# 214  2020         116607.06                   21061.39  2020-07-20
# 215  2015         145063.13                   16107.79  2015-01-17
# 216  2022          79391.88                   14131.30  2022-11-17
# 217  2019         118346.74                   15535.81  2019-08-19
# 218  2018         117327.36                   10689.15  2018-08-17
#
#            times_que_jogaram              classificacao_para_competicao  \
# 0    Cruzeiro vs Atlético-MG                                        não
# ...

# %%
df = pd.DataFrame()
df = pd.read_csv('../data.csv/perfil_demografico_torcida.csv')
df[df['Tipo_Metrica'] == 'Gênero']
# Out:
#    Jogo_ID      Competição  Público_Total_Jogo     Clube Tipo_Metrica  \
# 0   JOGO_1     Brasileirão               26557  CRUZEIRO       Gênero
# 1   JOGO_1     Brasileirão               26557  CRUZEIRO       Gênero
# 2   JOGO_1     Brasileirão               26557     BAHIA       Gênero
# 3   JOGO_1     Brasileirão               26557     BAHIA       Gênero
# 23  JOGO_2         Mineiro               47036  ATLÉTICO       Gênero
# 24  JOGO_2         Mineiro               47036  ATLÉTICO       Gênero
# 25  JOGO_2         Mineiro               47036   AMÉRICA       Gênero
# 26  JOGO_2         Mineiro               47036   AMÉRICA       Gênero
# 45  JOGO_3  Copa do Brasil               61583  CRUZEIRO       Gênero
# 46  JOGO_3  Copa do Brasil               61583  CRUZEIRO       Gênero
#
#     Categoria Valor_Percentual  Valor_Nominal
# 0   MASCULINO              65%          15536
# 1    FEMININO              35%           8365
# 2   MASCULINO              60%           1594
# ...
